# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.arange(0,20)
y = x**2

fig = plt.figure()       #creates blank figure
# adding new set of axes to figure
axes = fig.add_axes([0.1, 0.1, 0.9, 0.9])
# [left, bottom, width, height] of the new axes. All quantities are in fraction
axes.plot(x,y)
axes.set_xlabel("X axis")
axes.set_ylabel("Y axis")
axes.set_title("Square")
# Out:
# Text(0.5, 1.0, 'Square')

# %%
fig = plt.figure()       
axes1 = fig.add_axes([0, 0, 0.5, 0.5])
axes2 = fig.add_axes([0.7, 0, 1.2,1.2])

axes1.plot(x,y)
axes1.set_xlabel("X axis")
axes1.set_ylabel("Y axis")
axes1.set_title("Square")

axes2.plot(x,y, "ro")
axes2.set_xlabel("X axis")
axes2.set_ylabel("Y axis")
axes2.set_title("Square")
# Out:
# Text(0.5, 1.0, 'Square')

# %% [markdown]
# ## Multi plot using subplots

# %%
fig, axes = plt.subplots(nrows=2, ncols = 2)  #axes in a list object
axes[0][0].plot(x,y,"r")
axes[0][0].set_xlabel("X-Axis")
axes[0][0].set_ylabel("Y-Axis")

axes[0][1].plot(x,y,"y")
axes[0][1].set_xlabel("X-Axis")
axes[0][1].set_ylabel("Y-Axis")

axes[1][0].plot(x,y,"g")
axes[1][0].set_xlabel("X-Axis")
axes[1][0].set_ylabel("Y-Axis")

axes[1][1].plot(x,y,"b")
axes[1][1].set_xlabel("X-Axis")
axes[1][1].set_ylabel("Y-Axis")
# Out:
# Text(0, 0.5, 'Y-Axis')

# %%
# %matplotlib inline command is also necessary to view the plots directly in the notebook.
